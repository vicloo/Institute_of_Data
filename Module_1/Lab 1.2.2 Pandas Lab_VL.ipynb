# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
# get matplot to show charts inline
# %matplotlib inline

# %% [markdown]
# chrome://settings/content/cookies
#
# NOTE: Make sure third party cookies are not blocked.

# %%
#from google.colab import files
#uploaded = files.upload()
#import io
#df = pd.read_csv(io.BytesIO(uploaded["Employee-attrition.csv"]))

csv_file= 'C:/Users/victo/Documents/Institute_of_Data/DATA/Employee-attrition.csv'

df= pd.read_csv(csv_file)

# %%
df.head()
# Out:
#    EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0        1318  12/31/2006 0:00      1/3/1954        8/28/1989
# 1        1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 2        1318  12/31/2008 0:00      1/3/1954        8/28/1989
# 3        1318  12/31/2009 0:00      1/3/1954        8/28/1989
# 4        1318  12/31/2010 0:00      1/3/1954        8/28/1989
#
#   terminationdate_key  age  length_of_service  city_name department_name  \
# 0            1/1/1900   52                 17  Vancouver       Executive
# 1            1/1/1900   53                 18  Vancouver       Executive
# 2            1/1/1900   54                 19  Vancouver       Executive
# 3            1/1/1900   55                 20  Vancouver       Executive
# 4            1/1/1900   56                 21  Vancouver       Executive
#
#   job_title  store_name gender_short gender_full termreason_desc  \
# 0       CEO          35            M        Male  Not Applicable
# ...

# %%
df.tail()
# Out:
#        EmployeeID  recorddate_key birthdate_key orighiredate_key  \
# 49648        8258  12/1/2015 0:00     5/28/1994        8/19/2013
# 49649        8264   8/1/2013 0:00     6/13/1994        8/27/2013
# 49650        8279  12/1/2015 0:00     7/18/1994        9/15/2013
# 49651        8296  12/1/2013 0:00      9/2/1994        10/9/2013
# 49652        8321  12/1/2014 0:00    11/28/1994       11/24/2013
#
#       terminationdate_key  age  length_of_service    city_name  \
# 49648          12/30/2015   21                  2    Valemount
# 49649           8/30/2013   19                  0    Vancouver
# 49650          12/30/2015   21                  2   White Rock
# 49651          12/31/2013   19                  0      Kelowna
# 49652          12/30/2014   20                  1  Grand Forks
#
#         department_name     job_title  store_name gender_short gender_full  \
# 49648             Dairy  Dairy Person          34            M        Male
# ...

# %% [markdown]
# # Accessing the main DataFrame components

# %%
columns = df.columns
index = df.index
data = df.values #returning data into an array

# %%
columns
# Out:
# Index(['EmployeeID', 'recorddate_key', 'birthdate_key', 'orighiredate_key',
#        'terminationdate_key', 'age', 'length_of_service', 'city_name',
#        'department_name', 'job_title', 'store_name', 'gender_short',
#        'gender_full', 'termreason_desc', 'termtype_desc', 'STATUS_YEAR',
#        'STATUS', 'BUSINESS_UNIT'],
#       dtype='object')

# %%
index
# Out:
# RangeIndex(start=0, stop=49653, step=1)

# %%
data
# Out:
# array([[1318, '12/31/2006 0:00', '1/3/1954', ..., 2006, 'ACTIVE',
#         'HEADOFFICE'],
#        [1318, '12/31/2007 0:00', '1/3/1954', ..., 2007, 'ACTIVE',
#         'HEADOFFICE'],
#        [1318, '12/31/2008 0:00', '1/3/1954', ..., 2008, 'ACTIVE',
#         'HEADOFFICE'],
#        ...,
#        [8279, '12/1/2015 0:00', '7/18/1994', ..., 2015, 'TERMINATED',
#         'STORES'],
#        [8296, '12/1/2013 0:00', '9/2/1994', ..., 2013, 'TERMINATED',
#         'STORES'],
#        [8321, '12/1/2014 0:00', '11/28/1994', ..., 2014, 'TERMINATED',
#         'STORES']], dtype=object)

# %% [markdown]
# # 1. Understanding Data Types

# %% [markdown]
# #### 1.A Find Shape of Data Frame

# %%
df.shape #same shape function in numpy
# Out:
# (49653, 18)

# %% [markdown]
# #### 1.B Find Data Tyeps of Data Frame

# %%
df.dtypes
# Out:
# EmployeeID              int64
# recorddate_key         object
# birthdate_key          object
# orighiredate_key       object
# terminationdate_key    object
# age                     int64
# length_of_service       int64
# city_name              object
# department_name        object
# job_title              object
# store_name              int64
# gender_short           object
# gender_full            object
# termreason_desc        object
# termtype_desc          object
# STATUS_YEAR             int64
# STATUS                 object
# BUSINESS_UNIT          object
# dtype: object

# %%
#df.age = df.age.astype('str')  #function to change age datatype 'int64' to datatype 'object'

# %% [markdown]
# #### 1.C Find Number of Data Types in a Data Frame
#
#
#
# ```
# Expected Output:
# int64      5
# object    13
# dtype: int64
# ```

# %%
df.dtypes.value_counts()
# Out:
# object    13
# int64      5
# dtype: int64

# %% [markdown]
# #### 1.D Use Info
#
# Use info and explore difference.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49653 entries, 0 to 49652
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   EmployeeID           49653 non-null  int64
#  1   recorddate_key       49653 non-null  object
#  2   birthdate_key        49653 non-null  object
#  3   orighiredate_key     49653 non-null  object
#  4   terminationdate_key  49653 non-null  object
#  5   age                  49653 non-null  int64
#  6   length_of_service    49653 non-null  int64
#  7   city_name            49653 non-null  object
#  8   department_name      49653 non-null  object
#  9   job_title            49653 non-null  object
#  10  store_name           49653 non-null  int64
#  11  gender_short         49653 non-null  object
#  12  gender_full          49653 non-null  object
#  13  termreason_desc      49653 non-null  object
#  14  termtype_desc        49653 non-null  object
# ...

# %% [markdown]
# # 2. Selecting Column in Data Frame

# %% [markdown]
# #### 2.A Check Values of Job_Title column

# %%
df['job_title']
# Out:
# 0                 CEO
# 1                 CEO
# 2                 CEO
# 3                 CEO
# 4                 CEO
#              ...
# 49648    Dairy Person
# 49649         Cashier
# 49650         Cashier
# 49651         Cashier
# 49652         Cashier
# Name: job_title, Length: 49653, dtype: object

# %%
df.job_title  #another way to select column
# Out:
# 0                 CEO
# 1                 CEO
# 2                 CEO
# 3                 CEO
# 4                 CEO
#              ...
# 49648    Dairy Person
# 49649         Cashier
# 49650         Cashier
# 49651         Cashier
# 49652         Cashier
# Name: job_title, Length: 49653, dtype: object

# %% [markdown]
# #### 2.B Find How Many Rows Are in Each Job Title
#
#
#
# ```
# # Expected Output
# Meat Cutter                        9984
# Dairy Person                       8590
# Produce Clerk                      8237
# .
# .
# .
# ```

# %%
jobtitle = df.job_title
jobtitle.value_counts()  #or can use df.job_title.value_counts() - gives the same output
# Out:
# Meat Cutter                        9984
# Dairy Person                       8590
# Produce Clerk                      8237
# Baker                              8096
# Cashier                            6816
# Shelf Stocker                      5622
# Customer Service Manager            306
# Processed Foods Manager             289
# Bakery Manager                      285
# Meats Manager                       285
# Produce Manager                     278
# Store Manager                       271
# Recruiter                            62
# HRIS Analyst                         55
# Accounting Clerk                     50
# Benefits Admin                       35
# Accounts Receiveable Clerk           30
# Labor Relations Analyst              30
# Trainer                              26
# Accounts Payable Clerk               25
# Auditor                              20
# Compensation Analyst                 20
# Systems Analyst                      20
# ...

# %%
jobtitle = df.job_title
jobtitle.value_counts().head() #gives first 5 values
# Out:
# Meat Cutter      9984
# Dairy Person     8590
# Produce Clerk    8237
# Baker            8096
# Cashier          6816
# Name: job_title, dtype: int64

# %%
jobtitle = df.job_title
jobtitle.value_counts().head(20)
# Out:
# Meat Cutter                   9984
# Dairy Person                  8590
# Produce Clerk                 8237
# Baker                         8096
# Cashier                       6816
# Shelf Stocker                 5622
# Customer Service Manager       306
# Processed Foods Manager        289
# Bakery Manager                 285
# Meats Manager                  285
# Produce Manager                278
# Store Manager                  271
# Recruiter                       62
# HRIS Analyst                    55
# Accounting Clerk                50
# Benefits Admin                  35
# Accounts Receiveable Clerk      30
# Labor Relations Analyst         30
# Trainer                         26
# Accounts Payable Clerk          25
# Name: job_title, dtype: int64

# %%
jobtitle = df.job_title
jobtitle.value_counts(normalize=True) #normalize parameter gives you the proportion/percentage of the value counts
# Out:
# Meat Cutter                        0.201075
# Dairy Person                       0.173001
# Produce Clerk                      0.165891
# Baker                              0.163052
# Cashier                            0.137273
# Shelf Stocker                      0.113226
# Customer Service Manager           0.006163
# Processed Foods Manager            0.005820
# Bakery Manager                     0.005740
# Meats Manager                      0.005740
# Produce Manager                    0.005599
# Store Manager                      0.005458
# Recruiter                          0.001249
# HRIS Analyst                       0.001108
# Accounting Clerk                   0.001007
# Benefits Admin                     0.000705
# Accounts Receiveable Clerk         0.000604
# Labor Relations Analyst            0.000604
# Trainer                            0.000524
# Accounts Payable Clerk             0.000503
# Auditor                            0.000403
# ...

# %% [markdown]
# #### 2.C [BONUS] Write A Function to Row Count
#
#
#
# ```
# def row_count(column_name):
#     number_of_rows = 0
#     return number_of_rows
# ```

# %%
len(df.job_title) #will include all null values  OR df.job_title.count() #but count() will EXCLUDE null/blank values

# %%
def row_count(column_name):
    number_of_rows = len(column_name)
    return number_of_rows

# %%
row_count('job_title') #counts the number of letter
# Out:
# 9

# %%
row_count(df['job_title'])
# Out:
# 49653

# %% [markdown]
# #### 2.D Describe 'Age'
#
# Find count,  mean,  std, min, max of column 'age'

# %%
AGE=df.age
AGE.describe()
# Out:
# count    49653.000000
# mean        42.077035
# std         12.427257
# min         19.000000
# 25%         31.000000
# 50%         42.000000
# 75%         53.000000
# max         65.000000
# Name: age, dtype: float64

# %% [markdown]
# ##### 2.E [BONUS] Describe 'All Numeric Columns of Data Frame
#
# Find count, mean, std, min, max of of all columns of dataframe

# %%
df.describe()
# Out:
#          EmployeeID           age  length_of_service    store_name  \
# count  49653.000000  49653.000000       49653.000000  49653.000000
# mean    4859.495740     42.077035          10.434596     27.297605
# std     1826.571142     12.427257           6.325286     13.514134
# min     1318.000000     19.000000           0.000000      1.000000
# 25%     3360.000000     31.000000           5.000000     16.000000
# 50%     5031.000000     42.000000          10.000000     28.000000
# 75%     6335.000000     53.000000          15.000000     42.000000
# max     8336.000000     65.000000          26.000000     46.000000
#
#         STATUS_YEAR
# count  49653.000000
# mean    2010.612612
# std        2.845577
# min     2006.000000
# 25%     2008.000000
# 50%     2011.000000
# 75%     2013.000000
# max     2015.000000

# %%
df.describe().T #T= TRANSPOSE
# Out:
#                      count         mean          std     min     25%     50%  \
# EmployeeID         49653.0  4859.495740  1826.571142  1318.0  3360.0  5031.0
# age                49653.0    42.077035    12.427257    19.0    31.0    42.0
# length_of_service  49653.0    10.434596     6.325286     0.0     5.0    10.0
# store_name         49653.0    27.297605    13.514134     1.0    16.0    28.0
# STATUS_YEAR        49653.0  2010.612612     2.845577  2006.0  2008.0  2011.0
#
#                       75%     max
# EmployeeID         6335.0  8336.0
# age                  53.0    65.0
# length_of_service    15.0    26.0
# store_name           42.0    46.0
# STATUS_YEAR        2013.0  2015.0

# %%
df.describe(include='all')  #the parameter include='all' - means it will count ALL columns including non numerical ones
# Out:
#           EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# count   49653.000000            49653         49653            49653
# unique           NaN              130          5342             4415
# top              NaN  12/31/2013 0:00      8/4/1954       10/16/2005
# freq             NaN             5215            40               50
# mean     4859.495740              NaN           NaN              NaN
# std      1826.571142              NaN           NaN              NaN
# min      1318.000000              NaN           NaN              NaN
# 25%      3360.000000              NaN           NaN              NaN
# 50%      5031.000000              NaN           NaN              NaN
# 75%      6335.000000              NaN           NaN              NaN
# max      8336.000000              NaN           NaN              NaN
#
#        terminationdate_key           age  length_of_service  city_name  \
# ...

# %% [markdown]
# # 3. Making The Index Meaningful

# %%
df.set_index("EmployeeID", inplace=True)

# %%
df.head()
# Out:
#              recorddate_key birthdate_key orighiredate_key  \
# EmployeeID
# 1318        12/31/2006 0:00      1/3/1954        8/28/1989
# 1318        12/31/2007 0:00      1/3/1954        8/28/1989
# 1318        12/31/2008 0:00      1/3/1954        8/28/1989
# 1318        12/31/2009 0:00      1/3/1954        8/28/1989
# 1318        12/31/2010 0:00      1/3/1954        8/28/1989
#
#            terminationdate_key  age  length_of_service  city_name  \
# EmployeeID
# 1318                  1/1/1900   52                 17  Vancouver
# 1318                  1/1/1900   53                 18  Vancouver
# 1318                  1/1/1900   54                 19  Vancouver
# 1318                  1/1/1900   55                 20  Vancouver
# 1318                  1/1/1900   56                 21  Vancouver
#
#            department_name job_title  store_name gender_short gender_full  \
# EmployeeID
# 1318             Executive       CEO          35            M        Male
# ...

# %%
print(df.index)
# Out:
# Int64Index([1318, 1318, 1318, 1318, 1318, 1318, 1318, 1318, 1318, 1318,
#             ...
#             8188, 8214, 8223, 8226, 8231, 8258, 8264, 8279, 8296, 8321],
#            dtype='int64', name='EmployeeID', length=49653)

# %%
#turn employee id  to index instead of using index values itself, so we can search for employee id for info
#df.set_index("EmployeeID", inplace=True)  #inplace=True allows change to be applied to the original data

# %% [markdown]
# #### 3.A Find A Specifc Row Using Index

# %%
df.loc[8258]  #df.iloc[] - uses index number to locate observations
# Out:
#              recorddate_key birthdate_key orighiredate_key  \
# EmployeeID
# 8258        12/31/2013 0:00     5/28/1994        8/19/2013
# 8258        12/31/2014 0:00     5/28/1994        8/19/2013
# 8258         12/1/2015 0:00     5/28/1994        8/19/2013
#
#            terminationdate_key  age  length_of_service  city_name  \
# EmployeeID
# 8258                12/30/2015   19                  0  Valemount
# 8258                12/30/2015   20                  1  Valemount
# 8258                12/30/2015   21                  2  Valemount
#
#            department_name     job_title  store_name gender_short gender_full  \
# EmployeeID
# 8258                 Dairy  Dairy Person          34            M        Male
# 8258                 Dairy  Dairy Person          34            M        Male
# 8258                 Dairy  Dairy Person          34            M        Male
#
#            termreason_desc   termtype_desc  STATUS_YEAR      STATUS  \
# EmployeeID
# ...

# %%
df.loc[8264]
# Out:
# recorddate_key            8/1/2013 0:00
# birthdate_key                 6/13/1994
# orighiredate_key              8/27/2013
# terminationdate_key           8/30/2013
# age                                  19
# length_of_service                     0
# city_name                     Vancouver
# department_name        Customer Service
# job_title                       Cashier
# store_name                           44
# gender_short                          F
# gender_full                      Female
# termreason_desc              Resignaton
# termtype_desc                 Voluntary
# STATUS_YEAR                        2013
# STATUS                       TERMINATED
# BUSINESS_UNIT                    STORES
# Name: 8264, dtype: object

# %%
print('Details:', df.loc[8258])
# Out:
# Details:              recorddate_key birthdate_key orighiredate_key  \
# EmployeeID
# 8258        12/31/2013 0:00     5/28/1994        8/19/2013
# 8258        12/31/2014 0:00     5/28/1994        8/19/2013
# 8258         12/1/2015 0:00     5/28/1994        8/19/2013
#
#            terminationdate_key  age  length_of_service  city_name  \
# EmployeeID
# 8258                12/30/2015   19                  0  Valemount
# 8258                12/30/2015   20                  1  Valemount
# 8258                12/30/2015   21                  2  Valemount
#
#            department_name     job_title  store_name gender_short gender_full  \
# EmployeeID
# 8258                 Dairy  Dairy Person          34            M        Male
# 8258                 Dairy  Dairy Person          34            M        Male
# 8258                 Dairy  Dairy Person          34            M        Male
#
#            termreason_desc   termtype_desc  STATUS_YEAR      STATUS  \
# EmployeeID
# ...

# %% [markdown]
# #### 3.B Sort Data Frame using Index

# %%
df.sort_index(ascending=False)
# Out:
#              recorddate_key birthdate_key orighiredate_key  \
# EmployeeID
# 8336        12/31/2015 0:00    12/31/1994       12/11/2013
# 8336        12/31/2014 0:00    12/31/1994       12/11/2013
# 8336        12/31/2013 0:00    12/31/1994       12/11/2013
# 8335        12/31/2015 0:00    12/28/1994       12/10/2013
# 8335        12/31/2014 0:00    12/28/1994       12/10/2013
# ...                     ...           ...              ...
# 1318        12/31/2011 0:00      1/3/1954        8/28/1989
# 1318        12/31/2010 0:00      1/3/1954        8/28/1989
# 1318        12/31/2009 0:00      1/3/1954        8/28/1989
# 1318        12/31/2008 0:00      1/3/1954        8/28/1989
# 1318        12/31/2006 0:00      1/3/1954        8/28/1989
#
#            terminationdate_key  age  length_of_service  city_name  \
# EmployeeID
# 8336                  1/1/1900   21                  2  Vancouver
# 8336                  1/1/1900   20                  1  Vancouver
# ...

# %%
df.sort_index()
# Out:
#              recorddate_key birthdate_key orighiredate_key  \
# EmployeeID
# 1318        12/31/2006 0:00      1/3/1954        8/28/1989
# 1318        12/31/2007 0:00      1/3/1954        8/28/1989
# 1318        12/31/2008 0:00      1/3/1954        8/28/1989
# 1318        12/31/2009 0:00      1/3/1954        8/28/1989
# 1318        12/31/2010 0:00      1/3/1954        8/28/1989
# ...                     ...           ...              ...
# 8335        12/31/2013 0:00    12/28/1994       12/10/2013
# 8335        12/31/2015 0:00    12/28/1994       12/10/2013
# 8336        12/31/2015 0:00    12/31/1994       12/11/2013
# 8336        12/31/2013 0:00    12/31/1994       12/11/2013
# 8336        12/31/2014 0:00    12/31/1994       12/11/2013
#
#            terminationdate_key  age  length_of_service  city_name  \
# EmployeeID
# 1318                  1/1/1900   52                 17  Vancouver
# 1318                  1/1/1900   53                 18  Vancouver
# ...

# %% [markdown]
# #### 3.C [BONUS] Sort Data Frame using Age

# %%
df['age'].sort_values(ascending=False)   #or df.age.sort_values(ascending=False)
# Out:
# EmployeeID
# 2800    65
# 2674    65
# 2598    65
# 2599    65
# 2608    65
#         ..
# 8283    19
# 8222    19
# 8221    19
# 8284    19
# 8304    19
# Name: age, Length: 49653, dtype: int64

# %%
df.sort_values(['age'], ascending=[0])   #"notice different output"
# Out:
#              recorddate_key birthdate_key orighiredate_key  \
# EmployeeID
# 2800          6/1/2007 0:00      6/3/1942        12/9/1993
# 2674          2/1/2007 0:00     2/11/1942        8/19/1993
# 2598         11/1/2006 0:00    11/22/1941        5/30/1993
# 2599         11/1/2006 0:00    11/25/1941         6/2/1993
# 2608         12/1/2006 0:00     12/1/1941         6/8/1993
# ...                     ...           ...              ...
# 8283        12/31/2013 0:00     8/11/1994        9/27/2013
# 8222        12/31/2013 0:00      2/1/1994        6/18/2013
# 8221        12/31/2013 0:00     1/28/1994        6/16/2013
# 8284        12/31/2013 0:00     8/10/1994        9/27/2013
# 8304        12/31/2013 0:00     10/7/1994       10/27/2013
#
#            terminationdate_key  age  length_of_service        city_name  \
# EmployeeID
# 2800                  6/3/2007   65                 13    Prince George
# 2674                 2/11/2007   65                 13          Kelowna
# ...

# %% [markdown]
# #### 3.D [BONUS] Using Sample Select Any Row

# %%
df.sample(4) #number in parantheses will generate the number of samples you specify
# Out:
#              recorddate_key birthdate_key orighiredate_key  \
# EmployeeID
# 4151        12/31/2011 0:00      3/9/1964         9/3/1997
# 3430        12/31/2014 0:00     4/14/1960        8/12/1995
# 7967        12/31/2012 0:00     1/17/1992        5/20/2012
# 5948        12/31/2013 0:00      6/3/1976        2/19/2004
#
#            terminationdate_key  age  length_of_service      city_name  \
# EmployeeID
# 4151                  1/1/1900   47                 14  Williams Lake
# 3430                  1/1/1900   54                 19        Kelowna
# 7967                  1/1/1900   20                  0        Nanaimo
# 5948                  1/1/1900   37                  9     Aldergrove
#
#              department_name      job_title  store_name gender_short  \
# EmployeeID
# 4151                 Produce  Produce Clerk          40            F
# 3430                   Meats    Meat Cutter          16            F
# ...

# %% [markdown]
# # 4. Query Data Frame
#
# #### 4.A Find Rows Where Job_Title is CEO

# %%
df['job_title']
# Out:
# EmployeeID
# 1318             CEO
# 1318             CEO
# 1318             CEO
# 1318             CEO
# 1318             CEO
#             ...
# 8258    Dairy Person
# 8264         Cashier
# 8279         Cashier
# 8296         Cashier
# 8321         Cashier
# Name: job_title, Length: 49653, dtype: object

# %%
df['job_title'] == 'CEO'
# Out:
# EmployeeID
# 1318     True
# 1318     True
# 1318     True
# 1318     True
# 1318     True
#         ...
# 8258    False
# 8264    False
# 8279    False
# 8296    False
# 8321    False
# Name: job_title, Length: 49653, dtype: bool

# %%
df[df['job_title'] == 'CEO']  # equivalent to df.loc[df['job_title'] == 'CEO']
# Out:
#              recorddate_key birthdate_key orighiredate_key  \
# EmployeeID
# 1318        12/31/2006 0:00      1/3/1954        8/28/1989
# 1318        12/31/2007 0:00      1/3/1954        8/28/1989
# 1318        12/31/2008 0:00      1/3/1954        8/28/1989
# 1318        12/31/2009 0:00      1/3/1954        8/28/1989
# 1318        12/31/2010 0:00      1/3/1954        8/28/1989
# 1318        12/31/2011 0:00      1/3/1954        8/28/1989
# 1318        12/31/2012 0:00      1/3/1954        8/28/1989
# 1318        12/31/2013 0:00      1/3/1954        8/28/1989
# 1318        12/31/2014 0:00      1/3/1954        8/28/1989
# 1318        12/31/2015 0:00      1/3/1954        8/28/1989
#
#            terminationdate_key  age  length_of_service  city_name  \
# EmployeeID
# 1318                  1/1/1900   52                 17  Vancouver
# 1318                  1/1/1900   53                 18  Vancouver
# 1318                  1/1/1900   54                 19  Vancouver
# ...

# %% [markdown]
# #### 4.B Group By Age

# %%
df.groupby(['age'])

# %%
df.groupby(['age']).size()
# Out:
# age
# 19     158
# 20     408
# 21     703
# 22     815
# 23     960
# 24    1111
# 25    1197
# 26    1210
# 27    1235
# 28    1225
# 29    1227
# 30    1212
# 31    1146
# 32    1153
# 33    1164
# 34    1188
# 35    1189
# 36    1176
# 37    1149
# 38    1156
# 39    1142
# 40    1130
# 41    1135
# 42    1152
# 43    1150
# 44    1157
# 45    1141
# 46    1161
# 47    1173
# 48    1180
# 49    1196
# 50    1218
# 51    1207
# 52    1188
# 53    1188
# 54    1159
# 55    1168
# 56    1154
# 57    1130
# 58    1130
# 59    1128
# 60    1109
# 61     757
# 62     712
# 63     667
# 64     646
# 65     593
# dtype: int64

# %%
df.groupby(['age']).size().sort_values(ascending=False).head(10)
# Out:
# age
# 27    1235
# 29    1227
# 28    1225
# 50    1218
# 30    1212
# 26    1210
# 51    1207
# 25    1197
# 49    1196
# 35    1189
# dtype: int64

# %%
df.groupby(['age'])['gender_full'].value_counts()
# Out:
# age  gender_full
# 19   Female          86
#      Male            72
# 20   Female         209
#      Male           199
# 21   Female         362
#                    ...
# 63   Female         565
#      Male           102
# 64   Female         586
#      Male            60
# 65   Female         593
# Name: gender_full, Length: 93, dtype: int64

# %%
df.age.value_counts(ascending=True)
# Out:
# 19     158
# 20     408
# 65     593
# 64     646
# 63     667
# 21     703
# 62     712
# 61     757
# 22     815
# 23     960
# 60    1109
# 24    1111
# 59    1128
# 40    1130
# 58    1130
# 57    1130
# 41    1135
# 45    1141
# 39    1142
# 31    1146
# 37    1149
# 43    1150
# 42    1152
# 32    1153
# 56    1154
# 38    1156
# 44    1157
# 54    1159
# 46    1161
# 33    1164
# 55    1168
# 47    1173
# 36    1176
# 48    1180
# 52    1188
# 34    1188
# 53    1188
# 35    1189
# 49    1196
# 25    1197
# 51    1207
# 26    1210
# 30    1212
# 50    1218
# 28    1225
# 29    1227
# 27    1235
# Name: age, dtype: int64

# %% [markdown]
# # 5. Visualization
#
# > Indented block
#
#
#
# #### 5.A Plot Histogram of Age

# %%
plt.hist(df.age, bins=20)
# Out:
# (array([1269., 1775., 2308., 3670., 2439., 2299., 3541., 2325., 2298.,
#         2265., 3459., 2302., 2353., 3621., 2376., 2327., 3414., 2237.,
#         1469., 1906.]),
#  array([19. , 21.3, 23.6, 25.9, 28.2, 30.5, 32.8, 35.1, 37.4, 39.7, 42. ,
#         44.3, 46.6, 48.9, 51.2, 53.5, 55.8, 58.1, 60.4, 62.7, 65. ]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# #### 5.B BoxPlot of Age

# %%
plt.boxplot(df.age)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x16859adcfa0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x16859ae86a0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x16859adcc40>],
#  'medians': [<matplotlib.lines.Line2D at 0x16859ae8d60>],
#  'fliers': [<matplotlib.lines.Line2D at 0x16859af4100>],
#  'means': []}

# %% [markdown]
# #### 5.C Scatterplot of age and length_of_service

# %%
plt.scatter(df.age, df.length_of_service)
plt.show()

# %%
df.age
# Out:
# EmployeeID
# 1318    52
# 1318    53
# 1318    54
# 1318    55
# 1318    56
#         ..
# 8258    21
# 8264    19
# 8279    21
# 8296    19
# 8321    20
# Name: age, Length: 49653, dtype: int64

# %% [markdown]
# #### 5.D Plot Histogram of store_name

# %%
plt.hist(df.store_name)
# Out:
# (array([ 3403.,  3124.,  1379.,  9351.,  4495.,  2786.,  5698.,  3003.,
#          3689., 12725.]),
#  array([ 1. ,  5.5, 10. , 14.5, 19. , 23.5, 28. , 32.5, 37. , 41.5, 46. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# #### 5.E Print Statistical Summary of Age

# %%
from scipy import stats
stats.describe(df.age)
# Out:
# DescribeResult(nobs=49653, minmax=(19, 65), mean=42.077034620264634, variance=154.4367264677654, skewness=0.023093117697645202, kurtosis=-1.1473302603578608)

# %%
df['age'].describe()
# Out:
# count    49653.000000
# mean        42.077035
# std         12.427257
# min         19.000000
# 25%         31.000000
# 50%         42.000000
# 75%         53.000000
# max         65.000000
# Name: age, dtype: float64

# %%
df.age.describe()
# Out:
# count    49653.000000
# mean        42.077035
# std         12.427257
# min         19.000000
# 25%         31.000000
# 50%         42.000000
# 75%         53.000000
# max         65.000000
# Name: age, dtype: float64

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2021 Institute of Data
#
#
# ---
#
#
#
# ---

# %%
df.columns
# Out:
# Index(['recorddate_key', 'birthdate_key', 'orighiredate_key',
#        'terminationdate_key', 'age', 'length_of_service', 'city_name',
#        'department_name', 'job_title', 'store_name', 'gender_short',
#        'gender_full', 'termreason_desc', 'termtype_desc', 'STATUS_YEAR',
#        'STATUS', 'BUSINESS_UNIT'],
#       dtype='object')

# %%
df.rename(columns={'length_of_service': 'duration', 'age':'AGE'})  #add inplace=True to change original data
# Out:
#              recorddate_key birthdate_key orighiredate_key  \
# EmployeeID
# 1318        12/31/2006 0:00      1/3/1954        8/28/1989
# 1318        12/31/2007 0:00      1/3/1954        8/28/1989
# 1318        12/31/2008 0:00      1/3/1954        8/28/1989
# 1318        12/31/2009 0:00      1/3/1954        8/28/1989
# 1318        12/31/2010 0:00      1/3/1954        8/28/1989
# ...                     ...           ...              ...
# 8258         12/1/2015 0:00     5/28/1994        8/19/2013
# 8264          8/1/2013 0:00     6/13/1994        8/27/2013
# 8279         12/1/2015 0:00     7/18/1994        9/15/2013
# 8296         12/1/2013 0:00      9/2/1994        10/9/2013
# 8321         12/1/2014 0:00    11/28/1994       11/24/2013
#
#            terminationdate_key  AGE  duration    city_name   department_name  \
# EmployeeID
# 1318                  1/1/1900   52        17    Vancouver         Executive
# ...

# %%
df.columns.str.upper()
# Out:
# Index(['RECORDDATE_KEY', 'BIRTHDATE_KEY', 'ORIGHIREDATE_KEY',
#        'TERMINATIONDATE_KEY', 'AGE', 'LENGTH_OF_SERVICE', 'CITY_NAME',
#        'DEPARTMENT_NAME', 'JOB_TITLE', 'STORE_NAME', 'GENDER_SHORT',
#        'GENDER_FULL', 'TERMREASON_DESC', 'TERMTYPE_DESC', 'STATUS_YEAR',
#        'STATUS', 'BUSINESS_UNIT'],
#       dtype='object')

# %%
df[['age', 'city_name', 'length_of_service']]   #to select selective features
# Out:
#             age    city_name  length_of_service
# EmployeeID
# 1318         52    Vancouver                 17
# 1318         53    Vancouver                 18
# 1318         54    Vancouver                 19
# 1318         55    Vancouver                 20
# 1318         56    Vancouver                 21
# ...         ...          ...                ...
# 8258         21    Valemount                  2
# 8264         19    Vancouver                  0
# 8279         21   White Rock                  2
# 8296         19      Kelowna                  0
# 8321         20  Grand Forks                  1
#
# [49653 rows x 3 columns]

# %%
data_1 = df[['age', 'city_name', 'length_of_service']]
data_1.groupby('age').size()  #incorrect
# Out:
# age
# 19     158
# 20     408
# 21     703
# 22     815
# 23     960
# 24    1111
# 25    1197
# 26    1210
# 27    1235
# 28    1225
# 29    1227
# 30    1212
# 31    1146
# 32    1153
# 33    1164
# 34    1188
# 35    1189
# 36    1176
# 37    1149
# 38    1156
# 39    1142
# 40    1130
# 41    1135
# 42    1152
# 43    1150
# 44    1157
# 45    1141
# 46    1161
# 47    1173
# 48    1180
# 49    1196
# 50    1218
# 51    1207
# 52    1188
# 53    1188
# 54    1159
# 55    1168
# 56    1154
# 57    1130
# 58    1130
# 59    1128
# 60    1109
# 61     757
# 62     712
# 63     667
# 64     646
# 65     593
# dtype: int64

# %%
#add new column
df['new_column'] = 0   #can use this function to add/substract..etc between datas and generate a new column --aka feature engineering, eg df['new_age'] - df['old_age']
df.head()
# Out:
#    EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0        1318  12/31/2006 0:00      1/3/1954        8/28/1989
# 1        1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 2        1318  12/31/2008 0:00      1/3/1954        8/28/1989
# 3        1318  12/31/2009 0:00      1/3/1954        8/28/1989
# 4        1318  12/31/2010 0:00      1/3/1954        8/28/1989
#
#   terminationdate_key  age  length_of_service  city_name department_name  \
# 0            1/1/1900   52                 17  Vancouver       Executive
# 1            1/1/1900   53                 18  Vancouver       Executive
# 2            1/1/1900   54                 19  Vancouver       Executive
# 3            1/1/1900   55                 20  Vancouver       Executive
# 4            1/1/1900   56                 21  Vancouver       Executive
#
#   job_title  store_name gender_short gender_full termreason_desc  \
# 0       CEO          35            M        Male  Not Applicable
# ...

# %%
df['uppercity'] = len(df['department_name'])
df.head()
# Out:
#    EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0        1318  12/31/2006 0:00      1/3/1954        8/28/1989
# 1        1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 2        1318  12/31/2008 0:00      1/3/1954        8/28/1989
# 3        1318  12/31/2009 0:00      1/3/1954        8/28/1989
# 4        1318  12/31/2010 0:00      1/3/1954        8/28/1989
#
#   terminationdate_key  age  length_of_service  city_name department_name  \
# 0            1/1/1900   52                 17  Vancouver       Executive
# 1            1/1/1900   53                 18  Vancouver       Executive
# 2            1/1/1900   54                 19  Vancouver       Executive
# 3            1/1/1900   55                 20  Vancouver       Executive
# 4            1/1/1900   56                 21  Vancouver       Executive
#
#   job_title  store_name gender_short gender_full termreason_desc  \
# 0       CEO          35            M        Male  Not Applicable
# ...

# %%
for lab, row in cars.iterrows() :
    cars.loc[lab, "COUNTRY"] = (row["country"].upper())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-85e7d90f1b5e> in <module>
# ----> 1 df.groupby(['age']).size()
#
# NameError: name 'df' is not defined

# %%
for lab, row in df.iterrows() :
    df
