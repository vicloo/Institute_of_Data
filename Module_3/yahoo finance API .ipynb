# %%
import yfinance as yf
import pandas as pd
import seaborn as sns

from scipy import stats
from matplotlib import pyplot as plt

# %%
pip install yfinance
# Out:
# ...
#   Created wheel for yfinance: filename=yfinance-0.1.63-py2.py3-none-any.whl size=23909 sha256=5e2ccf3668ce2690412279061c60c425fe0df93679a2116d7c857b89b86bb597
#   Stored in directory: c:\users\victo\appdata\local\pip\cache\wheels\ec\cc\c1\32da8ee853d742d5d7cbd11ee04421222eb354672020b57297
# ...
#   Created wheel for multitasking: filename=multitasking-0.0.9-py3-none-any.whl size=8368 sha256=08a1e84a9a5e505b50a7c8f73ab9abee53d65aeb813d6eaca16bbb920d55e5ba
#   Stored in directory: c:\users\victo\appdata\local\pip\cache\wheels\57\6d\a3\a39b839cc75274d2acfb1c58bfead2f726c6577fe8c4723f13
# Successfully built yfinance multitasking
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
msft = yf.Ticker("MSFT")

# %%
msft.info
# Out:
# {'zip': '98052-6399',
#  'sector': 'Technology',
# ...

# %%
type(msft.info)
# Out:
# dict

# %%
df = msft.info

# %%
df_1 = pd.DataFrame.from_dict([df])

# %%
df_1
# Out:
#           zip      sector                                longBusinessSummary  \
# 0  98052-6399  Technology  Microsoft Corporation develops, licenses, and ...
#
#       city         phone state        country companyOfficers  \
# 0  Redmond  425 882 8080    WA  United States              []
#
#                     website  maxAge  ... fromCurrency  \
# 0  http://www.microsoft.com       1  ...         None
#
#   fiveYearAvgDividendYield  fiftyTwoWeekLow  bid  tradeable  dividendYield  \
# 0                     1.57           196.25  285      False         0.0078
#
#    bidSize   dayHigh  regularMarketPrice  \
# 0     1400  286.6401              284.91
#
#                                   logo_url
# 0  https://logo.clearbit.com/microsoft.com
#
# [1 rows x 150 columns]

# %%
msft.history(period='max')
# Out:
#                   Open        High         Low       Close      Volume  \
# Date
# 1986-03-13    0.056108    0.064359    0.056108    0.061608  1031788800
# 1986-03-14    0.061608    0.064909    0.061608    0.063809   308160000
# 1986-03-17    0.063809    0.065459    0.063809    0.064909   133171200
# 1986-03-18    0.064909    0.065459    0.062708    0.063258    67766400
# 1986-03-19    0.063258    0.063809    0.061608    0.062158    47894400
# ...                ...         ...         ...         ...         ...
# 2021-07-26  289.000000  289.690002  286.640015  289.049988    23154000
# 2021-07-27  289.429993  289.579987  282.950012  286.540009    32667900
# 2021-07-28  288.989990  290.149994  283.829987  286.220001    33551900
# 2021-07-29  286.239990  288.619995  286.079987  286.500000    18168300
# 2021-07-30  285.170013  286.660004  283.910004  284.910004    20940900
#
#             Dividends  Stock Splits
# Date
# 1986-03-13        0.0           0.0
# ...

# %%
msft.earnings
# Out:
#            Revenue     Earnings
# Year
# 2018  110360000000  16571000000
# 2019  125843000000  39240000000
# 2020  143015000000  44281000000
# 2021  168088000000  61271000000

# %%
msft.quarterly_earnings
# Out:
#              Revenue     Earnings
# Quarter
# 3Q2020   37154000000  13893000000
# 4Q2020   43076000000  15463000000
# 1Q2021   41706000000  15457000000
# 2Q2021   46152000000  16458000000

# %%
tlry = yf.Ticker('TLRY')

# %%
tlry.financials
# Out:
#                                          2020-05-31   2019-05-31  2018-05-31  \
# Research Development                      2568000.0    1391000.0    490000.0
# Effect Of Accounting Charges                   None         None        None
# Income Before Tax                       -80717000.0  -15645000.0  35856000.0
# Minority Interest                        25807000.0   28409000.0   9580000.0
# Net Income                              -84634000.0  -16499000.0  29448000.0
# Selling General Administrative          163983000.0  123803000.0  43648000.0
# Gross Profit                            190975000.0   75421000.0  40887000.0
# Ebit                                      2677000.0  -63857000.0  -7236000.0
# Operating Income                          2677000.0  -63857000.0  -7236000.0
# Other Operating Expenses                       None         None        None
# Interest Expense                        -34376000.0   -7775000.0  -1350000.0
# ...

# %%
tlry.cashflow
# Out:
#                                             2020-05-31   2019-05-31  \
# Investments                                 45489000.0   62531000.0
# Change To Liabilities                       59745000.0     691000.0
# Total Cashflows From Investing Activities  -93764000.0 -177885000.0
# Net Borrowings                              68966000.0  470853000.0
# Total Cash From Financing Activities       173945000.0  724550000.0
# Change To Operating Activities             -24515000.0  -11607000.0
# Issuance Of Stock                          104979000.0  253697000.0
# Net Income                                 -84634000.0  -16499000.0
# Change In Cash                             -53575000.0  491060000.0
# Total Cash From Operating Activities      -133756000.0  -55605000.0
# Depreciation                                48834000.0   22779000.0
# Other Cashflows From Investing Activities   26000000.0  -10949000.0
# Change To Inventory                       -119678000.0  -22151000.0
# ...

# %%
tlry.recommendations
# Out:
#                                          Firm        To Grade    From Grade  \
# Date
# 2018-08-13 11:05:23               Cowen & Co.      Outperform
# 2018-08-14 13:12:44              Roth Capital             Buy
# 2018-09-06 12:12:01      Northland Securities  Market Perform    Outperform
# 2018-10-09 15:53:36               Cowen & Co.      Outperform    Outperform
# 2018-10-16 11:40:53                 Benchmark             Buy
# 2019-01-09 12:40:40              PiperJaffray      Overweight
# 2019-02-21 13:03:21            Seaport Global         Neutral
# 2019-03-08 11:32:39                 Jefferies    Underperform
# 2019-04-12 13:24:13         Vertical Research            Sell
# 2019-05-03 12:10:16                 Jefferies            Hold  Underperform
# 2019-05-13 13:33:36  Alliance Global Partners            Hold
# 2019-05-15 11:45:15               BMO Capital  Market Perform  Underperform
# 2019-06-05 10:34:59               Oppenheimer         Perform
# ...

# %%
tlry.dividends
# Out:
# Series([], Name: Dividends, dtype: int64)

# %%
tlry.calendar
# Out:
#                                     0                    1
# Earnings Date     2021-08-09 00:00:00  2021-08-13 00:00:00
# Earnings Average                -0.07                -0.07
# Earnings Low                    -0.07                -0.07
# Earnings High                   -0.07                -0.07
# Revenue Average             561640000            561640000
# Revenue Low                 496500000            496500000
# Revenue High                697300000            697300000

# %%
tlry.earnings
# Out:
#         Revenue  Earnings
# Year
# 2017   20438000   4198000
# 2018   36917000  29448000
# 2019  237110000 -16499000
# 2020  542339000 -84634000

# %%
tlry.quarterly_earnings
# Out:
#            Revenue   Earnings
# Quarter
# 3Q2020   144689000   -5095000
# 4Q2020   160532000 -120598000
# 1Q2021   153638000 -360996000
# 1Q2021    48021000 -340955000

# %%
data = yf.download("SPY AAPL", start="2021-01-01", end="2021-07-30")
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
data
# Out:
#              Adj Close                   Close                    High  \
#                   AAPL         SPY        AAPL         SPY        AAPL
# Date
# 2020-12-31  132.267349  371.444244  132.690002  373.880005  134.740005
# 2021-01-04  128.997803  366.387390  129.410004  368.790009  133.610001
# 2021-01-05  130.592697  368.910828  131.009995  371.329987  131.740005
# 2021-01-06  126.196747  371.116394  126.599998  373.549988  131.050003
# 2021-01-07  130.502991  376.630249  130.919998  379.100006  131.630005
# ...                ...         ...         ...         ...         ...
# 2021-07-23  148.559998  439.940002  148.559998  439.940002  148.720001
# 2021-07-26  148.990005  441.019989  148.990005  441.019989  149.830002
# 2021-07-27  146.770004  439.010010  146.770004  439.010010  149.210007
# 2021-07-28  144.979996  438.829987  144.979996  438.829987  146.970001
# 2021-07-29  145.639999  440.649994  145.639999  440.649994  146.550003
#
# ...

# %%
tickers = yf.Tickers('TSLA FORD GE')

# %%
tickers
# Out:
# yfinance.Tickers object <TSLA,FORD,GE>

# %%
df2 = tickers.history(start="2021-01-01", end="2021-07-30")
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
df2
# Out:
#            Close                        Dividends            High             \
#             FORD         GE        TSLA      FORD   GE TSLA  FORD         GE
# Date
# 2020-12-31  1.82  10.783835  705.669983         0  0.0    0  1.86  10.813790
# 2021-01-04  1.88  10.454329  729.770020         0  0.0    0  1.92  10.883685
# 2021-01-05  1.89  10.753881  735.109985         0  0.0    0  1.92  10.863716
# 2021-01-06  1.85  11.342996  755.979980         0  0.0    0  2.03  11.602607
# 2021-01-07  1.91  11.253132  816.039978         0  0.0    0  1.98  11.552682
# ...          ...        ...         ...       ...  ...  ...   ...        ...
# 2021-07-23  2.58  12.710000  643.380005         0  0.0    0  2.66  12.880000
# 2021-07-26  2.59  12.920000  657.619995         0  0.0    0  2.64  12.940000
# 2021-07-27  2.62  13.080000  644.780029         0  0.0    0  2.63  13.470000
# 2021-07-28  2.56  13.130000  646.979980         0  0.0    0  2.63  13.480000
# ...

# %%
df2[['Volume']]
# Out:
#             Volume
#               FORD         GE      TSLA
# Date
# 2020-12-31   86900   47702300  49649900
# 2021-01-04  117800   79949500  48638200
# 2021-01-05  123100   83700300  32245200
# 2021-01-06  322000  131584600  44700000
# 2021-01-07   95200   75289800  51498900
# ...            ...        ...       ...
# 2021-07-23   96500   37743100  14581300
# 2021-07-26   79300   53706100  25044100
# 2021-07-27   56600  119249000  32756900
# 2021-07-28   54600   68509900  15970200
# 2021-07-29  149400   54276500  30394600
#
# [145 rows x 3 columns]

# %%
tesla = df2['Volume'][['TSLA' , 'FORD']]

# %%
tesla
# Out:
#                 TSLA    FORD
# Date
# 2020-12-31  49649900   86900
# 2021-01-04  48638200  117800
# 2021-01-05  32245200  123100
# 2021-01-06  44700000  322000
# 2021-01-07  51498900   95200
# ...              ...     ...
# 2021-07-23  14581300   96500
# 2021-07-26  25044100   79300
# 2021-07-27  32756900   56600
# 2021-07-28  15970200   54600
# 2021-07-29  30394600  149400
#
# [145 rows x 2 columns]

# %%
tesla.melt(var_name='Type', value_name='Volume')
# Out:
#      Type    Volume
# 0    TSLA  49649900
# 1    TSLA  48638200
# 2    TSLA  32245200
# 3    TSLA  44700000
# 4    TSLA  51498900
# ..    ...       ...
# 285  FORD     96500
# 286  FORD     79300
# 287  FORD     56600
# 288  FORD     54600
# 289  FORD    149400
#
# [290 rows x 2 columns]

# %%
df_melted = tesla.reset_index()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\envs\my_work\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'index'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-159-8913fd9774c7> in <module>
# ...

# %%
sns.lineplot(data=tesla, x='Date', y='TSLA');
sns.lineplot(data=tesla, x='Date', y='FORD');

plt.xticks(rotation=15);

plt.ylabel('Volume');

# %%
df2 = tickers.history(start="2010-01-01", end="2021-07-30")
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
df2
# Out:
#            Close                        Dividends            High             \
#             FORD         GE        TSLA      FORD   GE TSLA  FORD         GE
# Date
# 2009-12-31  2.10  10.757807         NaN         0  0.0  NaN  2.12  10.907122
# 2010-01-04  2.03  10.985333         NaN         0  0.0  NaN  2.09  11.120428
# 2010-01-05  2.00  11.042215         NaN         0  0.0  NaN  2.05  11.141760
# 2010-01-06  2.04  10.985333         NaN         0  0.0  NaN  2.06  11.106208
# 2010-01-07  2.00  11.554157         NaN         0  0.0  NaN  2.06  11.717693
# ...          ...        ...         ...       ...  ...  ...   ...        ...
# 2021-07-23  2.58  12.710000  643.380005         0  0.0  0.0  2.66  12.880000
# 2021-07-26  2.59  12.920000  657.619995         0  0.0  0.0  2.64  12.940000
# 2021-07-27  2.62  13.080000  644.780029         0  0.0  0.0  2.63  13.470000
# 2021-07-28  2.56  13.130000  646.979980         0  0.0  0.0  2.63  13.480000
# ...

# %%
tesla = df2['Volume'][['TSLA' , 'FORD']]

# %%
tesla
# Out:
#                   TSLA    FORD
# Date
# 2009-12-31         NaN   41600
# 2010-01-04         NaN   23300
# 2010-01-05         NaN   72200
# 2010-01-06         NaN   55700
# 2010-01-07         NaN   41900
# ...                ...     ...
# 2021-07-23  14581300.0   96500
# 2021-07-26  25044100.0   79300
# 2021-07-27  32756900.0   56600
# 2021-07-28  15970200.0   54600
# 2021-07-29  30394600.0  149400
#
# [2914 rows x 2 columns]

# %%
sns.lineplot(data=tesla, x='Date', y='TSLA');
sns.lineplot(data=tesla, x='Date', y='FORD');

plt.xticks(rotation=15);

plt.ylabel('Volume');

# %%
pd.DataFrame(tesla)
# Out:
#                   TSLA
# Date
# 2020-12-31  705.669983
# 2021-01-04  729.770020
# 2021-01-05  735.109985
# 2021-01-06  755.979980
# 2021-01-07  816.039978
# ...                ...
# 2021-07-23  643.380005
# 2021-07-26  657.619995
# 2021-07-27  644.780029
# 2021-07-28  646.979980
# 2021-07-29  677.349976
#
# [145 rows x 1 columns]

# %%
sns.lineplot(data=tlry1, x='Date', y='Volume')

# %%
tlry = yf.Ticker('TLRY')

# %%
tlry1 = tlry.history(start="2021-07-01", end="2021-07-30")

# %%
tlry1
# Out:
#                  Open       High        Low      Close     Volume  Dividends  \
# Date
# 2021-06-30  17.900000  18.400000  17.280001  18.080000   25452600          0
# 2021-07-01  18.030001  18.450001  17.600000  17.840000   16278000          0
# 2021-07-02  17.830000  17.910000  17.190001  17.230000   13154500          0
# 2021-07-06  17.139999  17.480000  16.690001  16.719999   12756900          0
# 2021-07-07  16.750000  16.940001  15.840000  16.230000   19486700          0
# 2021-07-08  15.480000  16.389999  15.410000  16.250000   12901900          0
# 2021-07-09  16.240000  16.370001  15.850000  16.170000   11822300          0
# 2021-07-12  16.020000  16.389999  15.730000  16.240000   11637400          0
# 2021-07-13  16.500000  17.420000  16.190001  16.320000   26745900          0
# 2021-07-14  16.760000  16.799999  14.950000  15.010000   27927000          0
# 2021-07-15  14.970000  15.340000  13.970000  14.400000   24352300          0
# ...

# %%
sns.lineplot(data=tlry1, x='Date', y='Volume')
sns.linepl
plt.figure(figsize=(12,8))

# %%
fig, ax1 = plt.subplots()

ax2 = ax1.twinx()

sns.lineplot(data=tlry1, x='Date', y='Volume', ax=ax2)
sns.lineplot(data=tlry1, x='Date', y='High', ax=ax1)

plt.xticks(rotation=90);

# %%
sns.lineplot(data=tlry1, x='Date', y='Volume')
sns.lineplot(data=tlry1, x='Date', y='High')

plt.xticks(rotation=90)
# Out:
# (array([18807., 18809., 18813., 18817., 18821., 18825., 18829., 18833.,
#         18837.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
sklearn.preprocessing.StandardScaler

# %%
sp500 = yf.Ticker('^GSPC')

# %%
sp500df = sp500.history(start="2021-07-01", end="2021-07-30")

# %%
sp500df
# Out:
#                    Open         High          Low        Close      Volume  \
# Date
# 2021-06-30  4290.649902  4302.430176  4287.959961  4297.500000  3687880000
# 2021-07-01  4300.729980  4320.660156  4300.729980  4319.939941  3077580000
# 2021-07-02  4326.600098  4355.430176  4326.600098  4352.339844  2628550000
# 2021-07-06  4356.459961  4356.459961  4314.370117  4343.540039  3437900000
# 2021-07-07  4351.009766  4361.879883  4329.790039  4358.129883  3243900000
# 2021-07-08  4321.069824  4330.879883  4289.370117  4320.819824  3393780000
# 2021-07-09  4329.379883  4371.600098  4329.379883  4369.549805  2738280000
# 2021-07-12  4372.410156  4386.680176  4364.029785  4384.629883  2983980000
# 2021-07-13  4381.069824  4392.370117  4366.919922  4369.209961  3166900000
# 2021-07-14  4380.109863  4393.680176  4362.359863  4374.299805  3213870000
# 2021-07-15  4369.020020  4369.020020  4340.700195  4360.029785  3226930000
# ...

# %%
import sklearn
from sklearn import preprocessing

# %%
sns.relplot(data=tlry1, x='Date', y='Volume', kind='line', ax=ax2)
sns.relplot(data=sp500df, x='Date', y='Volume', kind='line', ax=ax1)

sklearn.preprocessing.StandardScaler
# Out:
# C:\Users\victo\Anaconda3\envs\my_work\lib\site-packages\seaborn\relational.py:936: UserWarning: relplot is a figure-level function and does not accept the ax= paramter. You may wish to try lineplot
#   warnings.warn(msg, UserWarning)
# C:\Users\victo\Anaconda3\envs\my_work\lib\site-packages\seaborn\relational.py:936: UserWarning: relplot is a figure-level function and does not accept the ax= paramter. You may wish to try lineplot
#   warnings.warn(msg, UserWarning)
# sklearn.preprocessing._data.StandardScaler

# %%
sns.relplot(data=tlry1, x='Date', y='Volume', kind='line', ax=ax2)
sns.relplot(data=sp500df, x='Date', y='Volume', kind='line', ax=ax1)

sns.relplot(
    data=df.melt(id_vars=["x-axis", "group", "group2"], value_vars=["col1", "col2"]),
    x="Date", y="Volume", style="variable", hue="group", col="group2", kind="line")
# Out:
# C:\Users\victo\Anaconda3\envs\my_work\lib\site-packages\seaborn\relational.py:936: UserWarning: relplot is a figure-level function and does not accept the ax= paramter. You may wish to try lineplot
#   warnings.warn(msg, UserWarning)
# C:\Users\victo\Anaconda3\envs\my_work\lib\site-packages\seaborn\relational.py:936: UserWarning: relplot is a figure-level function and does not accept the ax= paramter. You may wish to try lineplot
#   warnings.warn(msg, UserWarning)

# %%
sns.relplot(
    data=df.melt(id_vars=["Date"], value_vars=["col1", "col2"]),
    x="Date", y="Volume", kind="line")
