# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %% [markdown]
# # Lab 4.1.2 Linear Regression

# %% [markdown]
# ## Prediction of House Price Using Linear Regression

# %% [markdown]
# ### Data
#
# The Sacramento real estate transactions file is a list of 985 real estate transactions in the Sacramento area reported over a five-day period, as reported by the Sacramento Bee.

# %%
import pandas as pd
import numpy as np
import seaborn as sns

from scipy import stats
from matplotlib import pyplot as plt

# %matplotlib inline

# %% [markdown]
# ### 1. Explore Data

# %% [markdown]
# Perform EDA on this dataset. Find Dependent and Independent Variables to predict house price.

# %%
# Read CSV
data = pd.read_csv("C:/Users/victo/Documents/Institute_of_Data/DATA/Sacramento_transactions.csv")

# %%
data.shape
# Out:
# (985, 12)

# %% [markdown]
# ### 2. Predict Price

# %% [markdown]
# We are going to predict `price` from available information.

# %% [markdown]
# #### 2.1 What is the Target Variable? Why?

# %%
# ANSWER

all same as lab 4.1.1

# %% [markdown]
# #### 2.2 List all possible variables which might be Independent/Predictor variable.

# %%
# ANSWER

all same as lab 4.1.1

# %% [markdown]
# #### 2.3 Find correlation between variables
#
# Find correlation between variables. Which is the best predictor? Why? State your reason.

# %%
# ANSWER

all same as lab 4.1.1

# %% [markdown]
# #### 2.4 Find Coefficient and Intercept using Linear Regression
#
# Using LinearRegression of sklearn.linear_model package find Coefficient and Intercept.
#
# Create an instance of LinearRegression.
#
# Explore following methods:
#
# - fit
# - predict
# - score

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ##### 2.4.1 Fit predictor and target variables using linear regression

# %%
# y = linreg.intercept_ + linreg.coef_ * x

# %%
# ANSWER

X = data['sq__ft'].values.reshape(-1,1)   
Y = data['price']

linreg = LinearRegression()
linreg.fit(X, Y)

print(linreg.coef_, linreg.intercept_)
# Out:
# [54.15863969] 162930.16140699777

# %%
data['sq__ft']
# Out:
# 0       836
# 1      1167
# 2       796
# 3       852
# 4       797
#        ...
# 980    2280
# 981    1477
# 982    1216
# 983    1685
# 984    1362
# Name: sq__ft, Length: 985, dtype: int64

# %%
data['price']
# Out:
# 0       59222
# 1       68212
# 2       68880
# 3       69307
# 4       81900
#         ...
# 980    232425
# 981    234000
# 982    235000
# 983    235301
# 984    235738
# Name: price, Length: 985, dtype: int64

# %%
data['sq__ft'].values
# Out:
# array([ 836, 1167,  796,  852,  797, 1122, 1104, 1177,  941, 1146,  909,
#        1289,  871, 1020, 1022, 1134,  844,  795,  588, 1356, 1118, 1329,
#        1240, 1601,  901, 1088,  963, 1119, 1380, 1248, 1039, 1152, 1380,
#        1116, 1039, 1418, 1082, 1472, 1146,  760, 1304, 1207, 1056, 1043,
#        1587, 1120, 1580, 1955, 1656, 1477, 1188, 1590, 1463, 1714, 1185,
#        1406, 1943, 1172, 1152, 1851, 1215, 1130, 1603, 1479, 1420, 1280,
#        1586, 1362, 2162, 1266, 1715, 1820,  936,    0, 1511, 1590, 1596,
#        1341, 2136, 1616, 1478, 1287, 1277, 1448, 2235, 2093, 1193, 2163,
#        1269,    0,  958, 2508, 1305, 1591, 1326, 1843, 1921, 2790, 1541,
#        1018,    0, 1672, 1380,  975, 2372, 1446, 1284, 3009, 3612, 2056,
#        1993, 1857, 1126, 2213, 2494, 1843, 1520, 2800, 2309, 2367, 3516,
#           0, 1914, 1690, 2725, 2354,    0, 2185, 1801, 1961, 3134, 1915,
#           0,    0, 2734, 2110, 3164, 3599, 2054, 1830, 1627, 3440, 2846,
# ...

# %%
data['sq__ft'].shape
# Out:
# (985,)

# %%
data['sq__ft'].values.reshape(-1,1)  
#to change from 1D array to 2D array, but dont need to change Y axis, only X axis
# Out:
# array([[ 836],
#        [1167],
#        [ 796],
#        [ 852],
#        [ 797],
#        [1122],
#        [1104],
#        [1177],
#        [ 941],
#        [1146],
#        [ 909],
#        [1289],
#        [ 871],
#        [1020],
#        [1022],
#        [1134],
#        [ 844],
#        [ 795],
#        [ 588],
#        [1356],
#        [1118],
#        [1329],
#        [1240],
#        [1601],
#        [ 901],
#        [1088],
#        [ 963],
#        [1119],
#        [1380],
#        [1248],
#        [1039],
#        [1152],
#        [1380],
#        [1116],
#        [1039],
#        [1418],
#        [1082],
#        [1472],
#        [1146],
#        [ 760],
#        [1304],
#        [1207],
#        [1056],
#        [1043],
#        [1587],
#        [1120],
#        [1580],
#        [1955],
#        [1656],
#        [1477],
#        [1188],
#        [1590],
#        [1463],
#        [1714],
#        [1185],
#        [1406],
#        [1943],
#        [1172],
# ...

# %%
data['sq__ft'].values.reshape(-1,1).shape
# Out:
# (985, 1)

# %% [markdown]
# ##### 2.4.2 Find R Score

# %% [markdown]
# The coefficient R^2 is defined as (1 - u/v), where u is the residual sum of squares ((y_true - y_pred) ** 2).sum() and v is the total sum of squares ((y_true - y_true.mean()) ** 2).sum().
#
# The best possible score is 1.0 and it can be negative (because the
# model can be arbitrarily worse).

# %% [markdown]
# Find $R^2$ Using ```score``` method of Linear Regression.

# %%
# ANSWER

linreg.score(X, Y)
# Out:
# 0.11148717682951437

# %%
#example:
    
x = 2000 #find predicted y 'price'

# %%
x = np.array(2000).reshape(-1,1)

# %%
#1. first way of predicting y
linreg.predict(x)
# Out:
# array([271247.44078406])

# %%
#2. second way of predicting y 'price'
y = linreg.intercept_ + linreg.coef_ * x
x = 2000

y
# Out:
# array([[271247.44078406]])

# %%
# How to plot linear regression on current data (using datacamp example)

X = data['sq__ft'].values.reshape(-1,1)   
Y = data['price']

linreg = LinearRegression()

prediction_space = np.linspace(min(X), max(X)).reshape(-1,1)  #"X"
linreg.fit(X, Y)
Y_predict = linreg.predict(prediction_space) #"Y"

# %%
plt.scatter(X, Y)
plt.plot(prediction_space, Y_predict, color='black', linewidth=3)

# %%
np.linspace(min(X), max(X))
# Out:
# array([[   0.        ],
#        [ 118.81632653],
#        [ 237.63265306],
#        [ 356.44897959],
#        [ 475.26530612],
#        [ 594.08163265],
#        [ 712.89795918],
#        [ 831.71428571],
#        [ 950.53061224],
#        [1069.34693878],
#        [1188.16326531],
#        [1306.97959184],
#        [1425.79591837],
#        [1544.6122449 ],
#        [1663.42857143],
#        [1782.24489796],
#        [1901.06122449],
#        [2019.87755102],
#        [2138.69387755],
#        [2257.51020408],
#        [2376.32653061],
#        [2495.14285714],
#        [2613.95918367],
#        [2732.7755102 ],
#        [2851.59183673],
#        [2970.40816327],
#        [3089.2244898 ],
#        [3208.04081633],
#        [3326.85714286],
#        [3445.67346939],
#        [3564.48979592],
#        [3683.30612245],
#        [3802.12244898],
#        [3920.93877551],
#        [4039.75510204],
#        [4158.57142857],
#        [4277.3877551 ],
#        [4396.20408163],
# ...

# %% [markdown]
# ### 3. Splitting Data

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# #### 3.1 Create training and testing subsets
#
# Hint: Using `train_test_split` Library.
#
# ```
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
# ```

# %%
# ANSWER
## Create training and testing subsets

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
print(X_train.shape, y_train.shape)
# Out:
# (788, 1) (788,)

# %%
print(X_test.shape, y_test.shape)
# Out:
# (197, 1) (197,)

# %%
X_train
# Out:
# array([[1882],
#        [2280],
#        [1624],
#        [1462],
#        [1939],
#        [1255],
#        [1262],
#        [ 948],
#        [   0],
#        [1116],
#        [1152],
#        [2504],
#        [   0],
#        [3397],
#        [2218],
#        [ 960],
#        [3192],
#        [   0],
#        [1637],
#        [2056],
#        [1436],
#        [1341],
#        [1082],
#        [1859],
#        [1277],
#        [1280],
#        [   0],
#        [ 838],
#        [1690],
#        [2503],
#        [   0],
#        [ 796],
#        [1672],
#        [ 696],
#        [1182],
#        [1678],
#        [1392],
#        [1229],
#        [1122],
#        [1185],
#        [3746],
#        [   0],
#        [2960],
#        [1058],
#        [2790],
#        [   0],
#        [1123],
#        [1683],
#        [1341],
#        [1231],
#        [1744],
#        [ 795],
#        [3229],
#        [1088],
#        [2235],
#        [ 909],
#        [1570],
#        [1382],
# ...

# %%
y_train
# Out:
# 963    219000
# 762    279000
# 334    839000
# 889    121500
# 529    423000
#         ...
# 106    280908
# 270    275000
# 860    610000
# 435    220000
# 102    265000
# Name: price, Length: 788, dtype: int64

# %% [markdown]
# #### 3.2 Check Shape, Sample of Test Train Data

# %%
# ANSWER
## Check training/test data

# %% [markdown]
# #### 3.3 Using Linear Regression Find The Score
#
# 1. Fit model using X_train, y_train
# 2. Find score using X_test, y_test

# %%
# ANSWER
linreg= LinearRegression()
linreg.fit(X_train, y_train)

print(linreg.coef_, linreg.intercept_)
# Out:
# [48.27732485] 169604.60292586414

# %%
linreg.score(X_test, y_test)
# Out:
# 0.19174123389849995

# %% [markdown]
# ### 4. Predict House Price
#
# Let's assume we have information of following house:
#
# - street:	1140 EDMONTON DR
# - city:	SACRAMENTO
# - zip:	95833
# - state:	CA
# - beds:	3
# - baths:	2
# - sq__ft:	1204
# - type:	Residential
#
# **Predict the price of this house using linear regression model.**

# %%
# ANSWER

new_x = 1204
Ypred = linreg.intercept_ + linreg.coef_ * new_x

# %%
Ypred
# Out:
# array([227730.50204809])

# %%
print('Predicted house price: ', Ypred[0])
# Out:
# Predicted house price:  227730.50204809417

# %%
x=1204.reshape(-1,1)
Ypred = linreg.predict(x)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-0fd9c3baf961> in <module>
# ----> 1 x=[1204].reshape(-1,1)
#       2 Ypred = linreg.predict(x)
#
# AttributeError: 'list' object has no attribute 'reshape'

# %%
x= [[1204]]
Ypred_1 = linreg.predict(x)

print('Predicted house price: ', Ypred_1[0])
# Out:
# Predicted house price:  227730.50204809417

# %% [markdown]
# #### Find the error

# %%
# Predict price from X_test

y_pred_from_test = linreg.predict(X_test)

y_pred_from_test
# Out:
# array([213343.85924209, 284601.19072416, 264324.71428618, 253558.8708441 ,
#        243324.0779754 , 169604.60292586, 169604.60292586, 261331.52014533,
#        169604.60292586, 169604.60292586, 221840.66841611, 169604.60292586,
#        224640.75325754, 169604.60292586, 223095.87886227, 246172.44014169,
#        207985.07618348, 208033.35350834, 169604.60292586, 314871.07340659,
#        257952.10740567, 235358.31937477, 282283.87913125, 230675.41886409,
#        226282.18230252, 248006.97848608, 263262.61313942, 222709.66026345,
#        246655.21339022, 258338.32600448, 230868.5281635 , 258965.93122756,
#        242261.97682865, 243082.69135114, 169604.60292586, 226282.18230252,
#        209964.44650243, 246896.60001448, 219764.74344746, 169604.60292586,
#        267607.57237614, 199053.7710858 , 169604.60292586, 280980.39136024,
#        258965.93122756, 248200.08778549, 237675.63096768, 292711.78129936,
# ...

# %%
y_pred_from_test [:10]
# Out:
# array([213343.85924209, 284601.19072416, 264324.71428618, 253558.8708441 ,
#        243324.0779754 , 169604.60292586, 169604.60292586, 261331.52014533,
#        169604.60292586, 169604.60292586])

# %%
res = y_test - y_pred_from_test
res
# Out:
# 613   -136343.859242
# 451    -48601.190724
# 731    -23353.714286
# 436    -32558.870844
# 275     50668.922025
#            ...
# 292    138373.918979
# 209    -71075.673388
# 506     88759.439091
# 49     -72910.211733
# 717    -12199.663578
# Name: price, Length: 197, dtype: float64

# %%
from sklearn.metrics import mean_squared_error  #similar to finding residuals "but we square the residuals"

mean_squared_error(y_test, y_pred_from_test, squared= True)
# Out:
# 16608820977.972658

# %%
"fit the models on training set, score the models on test set"

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2021 Institute of Data
#
#
# ---
#
#
#
# ---
